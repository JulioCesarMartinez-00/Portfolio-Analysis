# %% [markdown]
# # Download datasets

# %%
from getdata import getData

# %%
# Select stock prices 
assets = ['WMT','MRK','INTC','MSFT','MMM','AAPL','VZ','JNJ','KO','CSCO','PG','UNH','PFE','WBA','GS',
          'CAT','MCD','IBM','NKE','V','DIS','HD','TRV','RTX','AXP','CVX','JPM','XOM','BA']
# download
df_assets_close = getData(assets,start='1990-01-03',end='2021-01-31')
# Out:
# WMT
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MRK
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INTC
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MSFT
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MMM
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL
#
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VZ
#
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
# data
df_assets_close.head()
# Out:
#                  WMT        MRK      INTC      MSFT       MMM      AAPL  \
# Date
# 1990-01-03  5.890625  13.312500  1.093750  0.619792  20.34375  0.334821
# 1990-01-04  5.859375  13.104167  1.117188  0.638021  20.50000  0.335938
# 1990-01-05  5.796875  12.833333  1.109375  0.622396  20.15625  0.337054
# 1990-01-08  5.875000  13.000000  1.125000  0.631944  20.68750  0.339286
# 1990-01-09  5.718750  12.895833  1.156250  0.630208  20.68750  0.335938
#
#                    VZ       JNJ        KO        PG  ...       NKE       DIS  \
# Date                                                 ...
# 1990-01-03  25.574492  7.515625  4.804688  8.796875  ...  0.859375  9.515615
# 1990-01-04  24.590857  7.531250  4.781250  8.625000  ...  0.841797  9.505339
# 1990-01-05  24.028780  7.453125  4.742188  8.468750  ...  0.867188  9.536167
# 1990-01-08  24.225508  7.578125  4.843750  8.625000  ...  0.863281  9.608099
# 1990-01-09  23.551016  7.343750  4.804688  8.625000  ...  0.847656  9.597823
#
# ...
